# %% [markdown]
# ## Model Specific Negatives Evaluataion Using DiCE:

# %%
# Lambda values
lambdas = [0.00, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

# Raw distances

diabetes_l1_distances = [65.52, 71.86, 75.40, 81.70, 87.03, 86.59, 84.82]
diabetes_l2_distances = [45.32, 49.05, 50.67, 55.20, 58.59, 57.75, 56.51]

german_l1_distances = [1936.20, 2073.99, 2266.45, 2306.32, 2457.01, 2360.01, 2365.52]
german_l2_distances = [1922.67, 2059.00, 2249.98, 2290.33, 2440.29, 2343.72, 2349.24]

communities_l1_distances = [235070.98, 242599.94, 245003.19, 247936.50, 250490.75, 243805.35, 240204.35]
communities_l2_distances = [104277.61, 108270.41, 109321.76, 109649.19, 110146.32, 106919.98, 104593.39]

def calculate_pct_increase(values):
    baseline = values[0]
    return [(v - baseline) / baseline * 100 for v in values]

# Percentage increase from lambda = 0

diabetes_l1_pct_increase = calculate_pct_increase(diabetes_l1_distances)
diabetes_l2_pct_increase = calculate_pct_increase(diabetes_l2_distances)

german_l1_pct_increase = calculate_pct_increase(german_l1_distances)
german_l2_pct_increase = calculate_pct_increase(german_l2_distances)

communities_l1_pct_increase = calculate_pct_increase(communities_l1_distances)
communities_l2_pct_increase = calculate_pct_increase(communities_l2_distances)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(11, 7))
plt.style.use('default')
plt.plot(lambdas, diabetes_l1_pct_increase, marker='o', linestyle='-', color='darkred', label='Diabetes L1')
plt.plot(lambdas, diabetes_l2_pct_increase, marker='o', linestyle='--', color='red', label='Diabetes L2')

plt.plot(lambdas, german_l1_pct_increase, marker='s', linestyle='-', color='blue', label='German Credit L1')
plt.plot(lambdas, german_l2_pct_increase, marker='s', linestyle='--', color='lightblue', label='German Credit L2')

plt.plot(lambdas, communities_l1_pct_increase, marker='^', linestyle='-', color='green', label='Communities L1')
plt.plot(lambdas, communities_l2_pct_increase, marker='^', linestyle='--', color='lightgreen', label='Communities L2')

plt.xlabel('Lambda (λ)',fontsize=20)
plt.ylabel('Percentage Increase (%)',fontsize=20)
plt.legend(fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Specific evaluation Using CEM:

# %%
# Lambda values
lambdas = [0.00, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

# Raw distances

diabetes_l1_distances = [9.82,10.70,12.21,13.21,11.90,4.66,2.14]
diabetes_l2_distances = [6.12,6.61,7.39,7.86,7.01,2.93,1.36]

german_l1_distances = [2.06,2.26,3.53,4.16,6.11,4.17,4.67]
german_l2_distances = [1.01,1.08,1.72,1.90,2.85,1.72,1.93]


def calculate_pct_increase(values):
    baseline = values[0]
    return [(v - baseline) / baseline * 100 for v in values]

# Percentage increase from lambda = 0

diabetes_l1_pct_increase = calculate_pct_increase(diabetes_l1_distances)
diabetes_l2_pct_increase = calculate_pct_increase(diabetes_l2_distances)

german_l1_pct_increase = calculate_pct_increase(german_l1_distances)
german_l2_pct_increase = calculate_pct_increase(german_l2_distances)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(11, 7))
plt.style.use('default')
plt.plot(lambdas, diabetes_l1_pct_increase, marker='o', linestyle='-', color='darkred', label='Diabetes L1')
plt.plot(lambdas, diabetes_l2_pct_increase, marker='o', linestyle='--', color='red', label='Diabetes L2')

plt.plot(lambdas, german_l1_pct_increase, marker='s', linestyle='-', color='blue', label='German Credit L1')
plt.plot(lambdas, german_l2_pct_increase, marker='s', linestyle='--', color='lightblue', label='German Credit L2')

plt.xlabel('Lambda (λ)',fontsize=20)
plt.ylabel('Percentage Increase (%)',fontsize=20)
plt.legend(fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Same Instances evaluation Using DiCE:

# %%
# Lambda values
lambdas = [0.00, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

# Raw distances

diabetes_l1_distances = [66.28,72.52,77.83,82.28,87.07,86.40,85.14]
diabetes_l2_distances = [45.83,49.24,52.65,55.43,58.59,57.88,56.30]

german_l1_distances = [2142.61,2425.42,2884.57,2938.64,3220.39,3150.92,3262.82]
german_l2_distances = [2127.69,2409.79,2867.11,2920.50,3201.29,3132.62,3243.03]

communities_l1_distances = [235748.79,247430.63,252830.39,260065.58,266218.10,262394.55,262611.00]
communities_l2_distances = [104459.51,110824.83,113250.47,115663.92,118024.64,116182.08,115905.69]

def calculate_pct_increase(values):
    baseline = values[0]
    return [(v - baseline) / baseline * 100 for v in values]

# Percentage increase from lambda = 0

diabetes_l1_pct_increase = calculate_pct_increase(diabetes_l1_distances)
diabetes_l2_pct_increase = calculate_pct_increase(diabetes_l2_distances)

german_l1_pct_increase = calculate_pct_increase(german_l1_distances)
german_l2_pct_increase = calculate_pct_increase(german_l2_distances)

communities_l1_pct_increase = calculate_pct_increase(communities_l1_distances)
communities_l2_pct_increase = calculate_pct_increase(communities_l2_distances)

# %%
plt.figure(figsize=(11, 7))
plt.style.use('default')
plt.plot(lambdas, diabetes_l1_pct_increase, marker='o', linestyle='-', color='darkred', label='Diabetes L1')
plt.plot(lambdas, diabetes_l2_pct_increase, marker='o', linestyle='--', color='red', label='Diabetes L2')

plt.plot(lambdas, german_l1_pct_increase, marker='s', linestyle='-', color='blue', label='German Credit L1')
plt.plot(lambdas, german_l2_pct_increase, marker='s', linestyle='--', color='lightblue', label='German Credit L2')

plt.plot(lambdas, communities_l1_pct_increase, marker='^', linestyle='-', color='green', label='Communities L1')
plt.plot(lambdas, communities_l2_pct_increase, marker='^', linestyle='--', color='lightgreen', label='Communities L2')

plt.xlabel('Lambda (λ)',fontsize=20)
plt.ylabel('Percentage Increase (%)',fontsize=20)
plt.legend(fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Same Instances evaluation Using CEM:

# %%
# Lambda values
lambdas = [0.00, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30]

# Raw distances

diabetes_l1_distances = [9.84,10.94,12.75,13.83,12.60,5.54,4.61]
diabetes_l2_distances = [6.13,6.76,7.71,8.22,7.42,3.60,3.05]

german_l1_distances = [2.06,2.83,4.82,6.49,10.45,7.67,8.71]
german_l2_distances = [1.01,1.34,2.31,2.90,4.83,3.00,3.27]


def calculate_pct_increase(values):
    baseline = values[0]
    return [(v - baseline) / baseline * 100 for v in values]

# Percentage increase from lambda = 0

diabetes_l1_pct_increase = calculate_pct_increase(diabetes_l1_distances)
diabetes_l2_pct_increase = calculate_pct_increase(diabetes_l2_distances)

german_l1_pct_increase = calculate_pct_increase(german_l1_distances)
german_l2_pct_increase = calculate_pct_increase(german_l2_distances)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(11, 7))
plt.style.use('default')
plt.plot(lambdas, diabetes_l1_pct_increase, marker='o', linestyle='-', color='darkred', label='Diabetes L1')
plt.plot(lambdas, diabetes_l2_pct_increase, marker='o', linestyle='--', color='red', label='Diabetes L2')

plt.plot(lambdas, german_l1_pct_increase, marker='s', linestyle='-', color='blue', label='German Credit L1')
plt.plot(lambdas, german_l2_pct_increase, marker='s', linestyle='--', color='lightblue', label='German Credit L2')

plt.xlabel('Lambda (λ)',fontsize=20)
plt.ylabel('Percentage Increase (%)',fontsize=20)
plt.legend(fontsize=15)
plt.grid(True)
plt.tight_layout()
plt.show()
